# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_excel("Miete_Data.xlsx")

# %%
df.head()
# Out:
#    Preis  Number of rooms  Square Meeters  Distance from Marienplatz  \
# 0   1300              2.0           58.19                       17.9
# 1   1417              1.0           48.00                        5.7
# 2   1659              2.0           63.00                        5.7
# 3   1094              1.0           34.85                        3.4
# 4   1190              2.0           48.39                       18.2
#
#    Posted by
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 5 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Preis                      38 non-null     int64
#  1   Number of rooms            38 non-null     float64
#  2   Square Meeters             38 non-null     float64
#  3   Distance from Marienplatz  38 non-null     float64
#  4   Posted by                  38 non-null     int64
# dtypes: float64(3), int64(2)
# memory usage: 1.6 KB

# %%
df.describe()
# Out:
#              Preis  Number of rooms  Square Meeters  \
# count    38.000000        38.000000       38.000000
# mean   1318.736842         1.776316       50.191053
# std     221.394436         0.600646       13.265426
# min     890.000000         1.000000       30.000000
# 25%    1182.500000         1.000000       40.250000
# 50%    1270.000000         2.000000       50.700000
# 75%    1450.750000         2.000000       58.805000
# max    1705.000000         3.000000       76.900000
#
#        Distance from Marienplatz  Posted by
# count                  38.000000   38.000000
# mean                    7.886842    0.710526
# std                     4.113075    0.459606
# min                     0.800000    0.000000
# 25%                     5.025000    0.000000
# 50%                     6.950000    1.000000
# 75%                     9.750000    1.000000
# max                    18.200000    1.000000

# %%
sns.jointplot(data=df, x='Preis',y='Number of rooms')

# %%
sns.jointplot(data=df, x='Preis',y='Square Meeters')

# %%
sns.jointplot(data=df, x='Preis',y='Distance from Marienplatz')

# %%
sns.jointplot(data=df, x='Preis',y='Posted by')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-752e7a790b52> in <module>
# ----> 1 sns.jointplot(data=df, x='Preis',y='Posted by')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2054
#    2055     # Initialize the JointGrid object
# -> 2056     grid = JointGrid(
#    2057         data=data, x=x, y=y, hue=hue,
#    2058         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ...

# %%
sns.pairplot(df)

# %%
sns.lmplot(data=df, x='Distance from Marienplatz',y='Preis')

# %%
sns.lmplot(data=df, x='Number of rooms',y='Preis')

# %%
sns.lmplot(data=df, x='Square Meeters',y='Preis')

# %%
sns.lmplot(data=df, x='Posted by',y='Preis')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-74b82c631fc6> in <module>
# ----> 1 sns.lmplot(data=df, x='Posted by',y='Preis')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     583     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Preis', 'Number of rooms', 'Square Meeters',
#        'Distance from Marienplatz', 'Posted by '],
#       dtype='object')

# %%
X = df[['Number of rooms', 'Square Meeters','Distance from Marienplatz','Posted by ']]

# %%
y = df['Preis']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
 lm.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=1)

# %%
pd.DataFrame(lm.coef_, X.columns, columns=['Coeff'])
# Out:
#                                Coeff
# Number of rooms           -83.176424
# Square Meeters             16.339919
# Distance from Marienplatz  -3.986558
# Posted by                  27.513291
